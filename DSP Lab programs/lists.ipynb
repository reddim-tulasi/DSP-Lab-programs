# %%
import pandas as pd
a=pd.read_csv("DSP-100 extract.csv")
a
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes         Non-Travel        489                Hardware
# 1    26        No         Non-Travel        841                Hardware
# 2    48        No      Travel_Rarely        437         Human Resources
# 3    38       Yes      Travel_Rarely       1403  Research & Development
# 4    54       Yes         Non-Travel        993                Software
# ..  ...       ...                ...        ...                     ...
# 95   54        No         Non-Travel       1258         Human Resources
# 96   39       Yes  Travel_Frequently       1092                 Support
# 97   51        No         Non-Travel        977                Software
# 98   38       Yes  Travel_Frequently        810                Hardware
# 99   23        No         Non-Travel       1222         Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
# Age                         100 non-null int64
# Attrition                   100 non-null object
# BusinessTravel              100 non-null object
# DailyRate                   100 non-null int64
# Department                  100 non-null object
# DistanceFromHome            100 non-null int64
# Education                   100 non-null int64
# EducationField              100 non-null object
# EmployeeCount               100 non-null int64
# EmployeeNumber              100 non-null int64
# EnvironmentSatisfaction     100 non-null int64
# Gender                      100 non-null object
# HourlyRate                  100 non-null int64
# JobInvolvement              100 non-null int64
# JobLevel                    100 non-null int64
# JobRole                     100 non-null object
# JobSatisfaction             100 non-null int64
# MaritalStatus               100 non-null object
# ...

# %%
a.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   41       Yes     Non-Travel        489                Hardware
# 1   26        No     Non-Travel        841                Hardware
# 2   48        No  Travel_Rarely        437         Human Resources
# 3   38       Yes  Travel_Rarely       1403  Research & Development
# 4   54       Yes     Non-Travel        993                Software
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 9          1  Technical Degree              1
# 1                39          1           Medical              1
# 2                20          5             Other              1
# 3                38          3   Human Resources              1
# 4                22          3             Other              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %%
a.tail()
# Out:
#     Age Attrition     BusinessTravel  DailyRate       Department  \
# 95   54        No         Non-Travel       1258  Human Resources
# 96   39       Yes  Travel_Frequently       1092          Support
# 97   51        No         Non-Travel        977         Software
# 98   38       Yes  Travel_Frequently        810         Hardware
# 99   23        No         Non-Travel       1222  Human Resources
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 95                43          4             Other              1
# 96                31          5   Human Resources              1
# 97                14          1  Technical Degree              1
# 98                 4          5   Human Resources              1
# 99                16          4  Technical Degree              1
#
#     EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 95              96  ...                         3            80
# ...

# %%
a.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes         Non-Travel        489                Hardware
# 1   26        No         Non-Travel        841                Hardware
# 2   48        No      Travel_Rarely        437         Human Resources
# 3   38       Yes      Travel_Rarely       1403  Research & Development
# 4   54       Yes         Non-Travel        993                Software
# 5   27        No  Travel_Frequently        259  Research & Development
# 6   50       Yes  Travel_Frequently        647                Hardware
# 7   58       Yes         Non-Travel        668  Research & Development
# 8   56        No      Travel_Rarely       1031                Software
# 9   28        No  Travel_Frequently       1159         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                 9          1  Technical Degree              1
# ...

# %%
a.tail(30)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 70   53        No      Travel_Rarely       1068                Hardware
# 71   28       Yes         Non-Travel        511                 Support
# 72   31        No  Travel_Frequently       1469                 Support
# 73   40       Yes  Travel_Frequently       1381                   Sales
# 74   37        No         Non-Travel       1242                Hardware
# 75   19       Yes      Travel_Rarely        383  Research & Development
# 76   36        No  Travel_Frequently        844                   Sales
# 77   45        No  Travel_Frequently       1186         Human Resources
# 78   58        No         Non-Travel       1105                Hardware
# 79   24       Yes  Travel_Frequently        478                   Sales
# 80   47        No      Travel_Rarely       1398                Hardware
# 81   21        No         Non-Travel        268  Research & Development
# ...

# %%
a["Age"]
# Out:
# 0     41
# 1     26
# 2     48
# 3     38
# 4     54
#       ..
# 95    54
# 96    39
# 97    51
# 98    38
# 99    23
# Name: Age, Length: 100, dtype: int64

# %%
a[["Age","Department"]]
# Out:
#     Age              Department
# 0    41                Hardware
# 1    26                Hardware
# 2    48         Human Resources
# 3    38  Research & Development
# 4    54                Software
# ..  ...                     ...
# 95   54         Human Resources
# 96   39                 Support
# 97   51                Software
# 98   38                Hardware
# 99   23         Human Resources
#
# [100 rows x 2 columns]

# %%
a.min()
# Out:
# Age                                      19
# Attrition                                No
# BusinessTravel                   Non-Travel
# DailyRate                               112
# Department                         Hardware
# DistanceFromHome                          1
# Education                                 1
# EducationField              Human Resources
# EmployeeCount                             1
# EmployeeNumber                            1
# EnvironmentSatisfaction                   1
# Gender                               Female
# HourlyRate                               32
# JobInvolvement                            1
# JobLevel                                  1
# JobRole                           Developer
# JobSatisfaction                           1
# MaritalStatus                      Divorced
# MonthlyIncome                          2140
# MonthlyRate                           17681
# NumCompaniesWorked                        0
# ...

# %%
a.max()
# Out:
# Age                                           60
# Attrition                                    Yes
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1485
# Department                               Support
# DistanceFromHome                              50
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                               100
# EnvironmentSatisfaction                        4
# Gender                                      Male
# HourlyRate                                   199
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              50063
# ...

# %%
a.OverTime.min()
# Out:
# 'No'

# %%
a.OverTime.max()
# Out:
# 'Yes'

# %%
a.YearsAtCompany.min()
# Out:
# 1

# %%
a.YearsAtCompany .max()
# Out:
# 33

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a["Education"]>4
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 95    False
# 96     True
# 97    False
# 98     True
# 99    False
# Name: Education, Length: 100, dtype: bool

# %%
a.Education.count()
# Out:
# 100

# %%
a.loc[3]
# Out:
# Age                                             38
# Attrition                                      Yes
# BusinessTravel                       Travel_Rarely
# DailyRate                                     1403
# Department                  Research & Development
# DistanceFromHome                                38
# Education                                        3
# EducationField                     Human Resources
# EmployeeCount                                    1
# EmployeeNumber                                   4
# EnvironmentSatisfaction                          4
# Gender                                        Male
# HourlyRate                                      75
# JobInvolvement                                   1
# JobLevel                                         2
# JobRole                                  Developer
# JobSatisfaction                                  1
# MaritalStatus                              Married
# ...

# %%
a.loc[3,"Age"]
# Out:
# 38
