# %%
#program for getting URL from the html page/website
import re
page='<a href="https://www.google.com">'
print(page)
def geturl(page):
    start_link=page.find("< a href")
    start_quote=page.find('"',start_link)
    end_quote=page.find('"',start_quote+1)
    url=page[start_quote+1:end_quote]
    return url
url=geturl(page)
# Out:
# <a href="https://www.google.com">

# %%
import urllib.request
url='https://www.google.com/'
resp=urllib.request.urlopen(url)
page1=resp.read()
page=str(page1)
def geturl(page):
    start_link=page.find("<a href")
    start_quote=page.find('""',start_link)
    end_quote=page.find('""',start_quote+1)
    url=page[start_quote+1:end_quote]
    return url,end_quote
while True:
    url,n=geturl(page)
    page=page[n:]
    if url:
        print(url)
    else:
        break
# Out:
# "><input name="ie" value="ISO-8859-1" type="hidden"><input value="en-IN" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><input class="lst" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000" autocomplete="off" value=
# ",

# %%
#printing links by using libraries:
import requests
page=requests.get('https://www.google.com/')
print(page)
print(page.content)
print(page.URL)
# Out:
# <Response [200]>
# ...

# %%
#to get the title of given website:
from bs4 import BeautifulSoup
Soup=BeautifulSoup(page.content,'html.parser')
page_title=Soup.title.text
print(page_title)
# Out:
# Google

# %%
#to get the body of the website
page_body=Soup.body
print(page_body)
# Out:
# <body bgcolor="#fff"><script nonce="LWsqZzq9xcCHP1dKqkwkFw">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# ...

# %%
#to get the head of the website

page_head=Soup.head
print(page_head)
# Out:
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Google</title><script nonce="LWsqZzq9xcCHP1dKqkwkFw">(function(){window.google={kEI:'FYr_YqS-IOnu4-EPjKOkmAU',kEXPI:'0,1302536,56873,6058,207,4804,2316,383,246,5,5367,1123753,1197719,682,380089,16115,19398,9286,17572,4858,1362,9291,3022,4751,12835,4998,13226,3849,10626,14758,7981,5079,1593,1279,2451,291,149,1103,842,2195,4100,3499,15,606,2023,2298,14677,3221,2844,6,24990,8781,1850,2614,13142,3,346,230,1014,1,5445,148,11323,2652,4,1528,2304,7039,22023,3050,2658,7355,13660,4437,16786,5821,2536,4094,4052,3,3541,1,42157,2,14019,2715,3287,8114,11623,5679,1020,2381,28741,4568,6253,23422,1254,3370,2465,12200,2767,4333,8,6082,1394,445,2,2,1,24626,2006,8155,6582,799,2,14678,1289,873,625,2463,2091,6753,7702,7,1922,9779,23,6865,12242,4562,28,703,6899,1744,1628,1460,3789,2165,1980,3667,3879,552,977,7,122,700,4,1,2,2,2,2,16
# ...

# %%
#Handling missing values
import pandas as pd
import numpy as np
d=pd.read_excel("DSPP MARKS.xlsx")
d
# Out:
#     Unnamed: 0  S.NO CLASS     ID NO SUBJECT  MARKS
# 0            0     1    2E   S180233     DSP     40
# 1            1     2    2C   S180462      WT     35
# 2            2     3    2B  S1801010     IOR     38
# 3            3     4    2A  S1801018      WT     35
# 4            4     5    2D   S180432      WT     32
# 5            5     6    2E   S180056     IOR     34
# 6            6     7    2B   S180255     DSP     20
# 7            7     8    2C   S180465      WT     39
# 8            8     9    2C   S180455      CD     40
# 9            9    10    2E   S180222     COA     23
# 10          10    11    2A   S180234      CD     38

# %%
d.dropna()
# Out:
#     Unnamed: 0  S.NO CLASS     ID NO SUBJECT  MARKS
# 0            0     1    2E   S180233     DSP     40
# 1            1     2    2C   S180462      WT     35
# 2            2     3    2B  S1801010     IOR     38
# 3            3     4    2A  S1801018      WT     35
# 4            4     5    2D   S180432      WT     32
# 5            5     6    2E   S180056     IOR     34
# 6            6     7    2B   S180255     DSP     20
# 7            7     8    2C   S180465      WT     39
# 8            8     9    2C   S180455      CD     40
# 9            9    10    2E   S180222     COA     23
# 10          10    11    2A   S180234      CD     38

# %%
d.drop(d.iloc[:,1:2],inplace=True,axis=1)
d
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP     40
# 1            1    2C   S180462      WT     35
# 2            2    2B  S1801010     IOR     38
# 3            3    2A  S1801018      WT     35
# 4            4    2D   S180432      WT     32
# 5            5    2E   S180056     IOR     34
# 6            6    2B   S180255     DSP     20
# 7            7    2C   S180465      WT     39
# 8            8    2C   S180455      CD     40
# 9            9    2E   S180222     COA     23
# 10          10    2A   S180234      CD     38

# %%
d.drop([1],axis=0)
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP     40
# 2            2    2B  S1801010     IOR     38
# 3            3    2A  S1801018      WT     35
# 4            4    2D   S180432      WT     32
# 5            5    2E   S180056     IOR     34
# 6            6    2B   S180255     DSP     20
# 7            7    2C   S180465      WT     39
# 8            8    2C   S180455      CD     40
# 9            9    2E   S180222     COA     23
# 10          10    2A   S180234      CD     38

# %%
d.drop(d.columns[[0,2]],axis=1)
# Out:
#    CLASS SUBJECT  MARKS
# 0     2E     DSP   1.00
# 1     2C      WT   0.75
# 2     2B     IOR   0.90
# 3     2A      WT   0.75
# 4     2D      WT   0.60
# 5     2E     IOR   0.70
# 6     2B     DSP   0.00
# 7     2C      WT   0.95
# 8     2C      CD   1.00
# 9     2E     COA   0.15
# 10    2A      CD   0.90

# %%
d.replace(np.nan,0)
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP     40
# 1            1    2C   S180462      WT     35
# 2            2    2B  S1801010     IOR     38
# 3            3    2A  S1801018      WT     35
# 4            4    2D   S180432      WT     32
# 5            5    2E   S180056     IOR     34
# 6            6    2B   S180255     DSP     20
# 7            7    2C   S180465      WT     39
# 8            8    2C   S180455      CD     40
# 9            9    2E   S180222     COA     23
# 10          10    2A   S180234      CD     38

# %%
a=d.dropna(how="all")
a
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP     40
# 1            1    2C   S180462      WT     35
# 2            2    2B  S1801010     IOR     38
# 3            3    2A  S1801018      WT     35
# 4            4    2D   S180432      WT     32
# 5            5    2E   S180056     IOR     34
# 6            6    2B   S180255     DSP     20
# 7            7    2C   S180465      WT     39
# 8            8    2C   S180455      CD     40
# 9            9    2E   S180222     COA     23
# 10          10    2A   S180234      CD     38

# %%
#Normalization
column="MARKS"
d["MARKS"]=(d["MARKS"]/d["MARKS"].abs().max())
d
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP  1.000
# 1            1    2C   S180462      WT  0.875
# 2            2    2B  S1801010     IOR  0.950
# 3            3    2A  S1801018      WT  0.875
# 4            4    2D   S180432      WT  0.800
# 5            5    2E   S180056     IOR  0.850
# 6            6    2B   S180255     DSP  0.500
# 7            7    2C   S180465      WT  0.975
# 8            8    2C   S180455      CD  1.000
# 9            9    2E   S180222     COA  0.575
# 10          10    2A   S180234      CD  0.950

# %%
d["MARKS"]=(d["MARKS"]-d["MARKS"].min())/(d["MARKS"].max()-d["MARKS"].min())
d
# Out:
#     Unnamed: 0 CLASS     ID NO SUBJECT  MARKS
# 0            0    2E   S180233     DSP   1.00
# 1            1    2C   S180462      WT   0.75
# 2            2    2B  S1801010     IOR   0.90
# 3            3    2A  S1801018      WT   0.75
# 4            4    2D   S180432      WT   0.60
# 5            5    2E   S180056     IOR   0.70
# 6            6    2B   S180255     DSP   0.00
# 7            7    2C   S180465      WT   0.95
# 8            8    2C   S180455      CD   1.00
# 9            9    2E   S180222     COA   0.15
# 10          10    2A   S180234      CD   0.90
